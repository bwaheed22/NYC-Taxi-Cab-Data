# %% [markdown]
# # Analysis of NYC Taxi Cab Data

# %% [markdown]
# ## Import Libraries and Connect to Database

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Connect to database:
con = sqlite3.connect("NYC-Taxi.db")

# %% [markdown]
# ## Extract Observations and Clean Data

# %% [markdown]
# We will extract a sample of 1,000,000 observations consisting of green and yellow cab data to explore the characteristics of taxi rides in NYC's boroughs and surrounding areas.

# %%
# Store sample of green and yellow cab data into dataframes:
df1 = pd.read_sql(f"SELECT * FROM green_cabs ORDER BY random() LIMIT 500000", con)
df2 = pd.read_sql(f"SELECT * from yellow_cabs ORDER BY random() LIMIT 500000", con)

# Add labels for green and yellow cabs and rename pickup/dropoff datetime columns:
df1 = df1.rename(columns={"lpep_pickup_datetime": "pickup_datetime", "lpep_dropoff_datetime":"dropoff_datetime"})
df2 = df2.rename(columns={"tpep_pickup_datetime": "pickup_datetime", "tpep_dropoff_datetime":"dropoff_datetime"})
df1['cab'] = "green"
df2['cab'] = "yellow"

# Combine into one data frame:
frames = [df1, df2]
df = pd.concat(frames)

# Change format to datetime where necessary:
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'],unit='s')
df['dropoff_datetime'] = pd.to_datetime(df['dropoff_datetime'],unit='s')

df.head()
# Out:
#    VendorID     pickup_datetime    dropoff_datetime store_and_fwd_flag  \
# 0       2.0 2019-08-05 16:28:17 2019-08-05 16:36:20                  N
# 1       2.0 2019-03-09 11:27:20 2019-03-09 12:09:38                  N
# 2       NaN 2019-12-18 09:44:00 2019-12-18 09:54:00               None
# 3       1.0 2019-12-13 07:36:42 2019-12-13 07:47:25                  N
# 4       1.0 2019-10-14 13:56:43 2019-10-14 14:37:35                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           262              1.0           1.28
# 1         5.0            92            55              1.0          20.83
# 2         NaN           165            85              NaN           2.11
# 3         1.0            41            42              1.0           1.60
# 4         1.0            75           125              1.0           8.20
#
#    fare_amount  ...  tip_amount  tolls_amount  ehail_fee  \
# 0         7.00  ...        2.89           0.0        NaN
# 1        56.37  ...        0.00           0.0        NaN
# 2        19.82  ...        0.00           0.0        NaN
# 3         9.00  ...        0.00           0.0        NaN
# 4        32.50  ...        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3         14.44           1.0        1.0
# 1                    0.0         56.87           1.0        2.0
# 2                    0.3         22.87           NaN        NaN
# 3                    0.3          9.80           2.0        1.0
# 4                    0.3         36.05           2.0        1.0
#
#    congestion_surcharge                 Source_file    cab
# 0                  2.75  green_tripdata_2019-08.csv  green
# 1                  0.00  green_tripdata_2019-03.csv  green
# 2                   NaN  green_tripdata_2019-12.csv  green
# 3                  0.00  green_tripdata_2019-12.csv  green
# 4                  2.75  green_tripdata_2019-10.csv  green
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# To better understand the data, we will add the following features to the main dataset:
#
# * Borough = the borough the passenger is picked up in.
# * Zone = the zone the passenger is picked up in (e.g. East Elmhurst).
# * trip_time = total trip time.
# * trip_speed = average speed of the trip (in miles per hour).

# %%
# Include pickup borough:

#Store Pickup location borough names and merge to main data frame:
df_location = pd.read_csv("/Users/mbp/Documents/Side Projects/NYC Taxi Cab Scratch/taxi+_zone_lookup.csv")
df_location['DOLocationID'] = df_location['LocationID']
df_location = df_location.rename(columns = {'LocationID':'PULocationID'})

# Add borough and Zone name:
df = df.merge(df_location[['PULocationID', 'Borough', 'Zone']], on = "PULocationID", how = 'left')

# Include trip time:
df['trip_time'] = (df['dropoff_datetime'] - df['pickup_datetime']).astype('timedelta64[m]')

# Include trip speed:
df['trip_speed'] = ((df['trip_distance'])/(df['trip_time']))*60

df.head()
# Out:
#    VendorID     pickup_datetime    dropoff_datetime store_and_fwd_flag  \
# 0       2.0 2019-08-05 16:28:17 2019-08-05 16:36:20                  N
# 1       2.0 2019-03-09 11:27:20 2019-03-09 12:09:38                  N
# 2       NaN 2019-12-18 09:44:00 2019-12-18 09:54:00               None
# 3       1.0 2019-12-13 07:36:42 2019-12-13 07:47:25                  N
# 4       1.0 2019-10-14 13:56:43 2019-10-14 14:37:35                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            75           262              1.0           1.28
# 1         5.0            92            55              1.0          20.83
# 2         NaN           165            85              NaN           2.11
# 3         1.0            41            42              1.0           1.60
# 4         1.0            75           125              1.0           8.20
#
#    fare_amount  ...  total_amount  payment_type  trip_type  \
# 0         7.00  ...         14.44           1.0        1.0
# 1        56.37  ...         56.87           1.0        2.0
# 2        19.82  ...         22.87           NaN        NaN
# 3         9.00  ...          9.80           2.0        1.0
# 4        32.50  ...         36.05           2.0        1.0
#
#    congestion_surcharge                 Source_file    cab    Borough  \
# 0                  2.75  green_tripdata_2019-08.csv  green  Manhattan
# 1                  0.00  green_tripdata_2019-03.csv  green     Queens
# 2                   NaN  green_tripdata_2019-12.csv  green   Brooklyn
# 3                  0.00  green_tripdata_2019-12.csv  green  Manhattan
# 4                  2.75  green_tripdata_2019-10.csv  green  Manhattan
#
#                 Zone  trip_time  trip_speed
# 0  East Harlem South        8.0    9.600000
# 1           Flushing       42.0   29.757143
# 2            Midwood       10.0   12.660000
# 3     Central Harlem       10.0    9.600000
# 4  East Harlem South       40.0   12.300000
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# We will examine summary statistics of all variables to get a better look at the structure of the data, and to see if there are apparent outliers.

# %%
# Summary stats and structure of data:
df.describe()
# Out:
#             VendorID     RatecodeID    PULocationID    DOLocationID  \
# count  964310.000000  964310.000000  1000000.000000  1000000.000000
# mean        1.739731       1.121494      135.733788      145.395178
# std         0.450038       0.828691       74.130092       75.201297
# min         1.000000       1.000000        1.000000        1.000000
# 25%         1.000000       1.000000       74.000000       75.000000
# 50%         2.000000       1.000000      137.000000      145.000000
# 75%         2.000000       1.000000      196.000000      226.000000
# max         4.000000      99.000000      265.000000      265.000000
#
#        passenger_count   trip_distance     fare_amount           extra  \
# count    964310.000000  1000000.000000  1000000.000000  1000000.000000
# mean          1.440658        3.231042       13.865785        0.813079
# std           1.107623       77.945840       12.822496        1.100885
# min           0.000000      -29.940000     -300.000000       -4.500000
# 25%           1.000000        1.000000        6.500000        0.000000
# 50%           1.000000        1.780000       10.000000        0.500000
# 75%           1.000000        3.500000       16.000000        1.000000
# max           9.000000    77843.760000     2156.000000       17.500000
#
#               mta_tax      tip_amount    tolls_amount  ehail_fee  \
# count  1000000.000000  1000000.000000  1000000.000000       25.0
# mean         0.488691        1.590615        0.319719        0.0
# std          0.082523        2.552719        1.708369        0.0
# min         -0.500000       -7.990000      -40.500000        0.0
# 25%          0.500000        0.000000        0.000000        0.0
# 50%          0.500000        1.000000        0.000000        0.0
# 75%          0.500000        2.360000        0.000000        0.0
# max          4.410000      400.000000      612.000000        0.0
#
#        improvement_surcharge    total_amount   payment_type      trip_type  \
# count         1000000.000000  1000000.000000  964310.000000  465792.000000
# mean                0.283850       18.174479       1.362257       1.044333
# std                 0.070922       14.904492       0.505524       0.205834
# min                -0.300000     -300.300000       1.000000       1.000000
# 25%                 0.300000        9.800000       1.000000       1.000000
# 50%                 0.300000       13.800000       1.000000       1.000000
# 75%                 0.300000       20.800000       2.000000       1.000000
# max                 1.000000     2156.300000       5.000000       2.000000
#
#        congestion_surcharge       trip_time  trip_speed
# count         891813.000000  1000000.000000   991232.00
# mean               1.343572       19.319173         inf
# std                1.269052       80.754113         NaN
# min               -2.750000      -52.000000      -44.13
# 25%                0.000000        6.000000        8.28
# 50%                2.500000       11.000000       11.00
# 75%                2.500000       19.000000       14.94
# max                2.750000     4661.000000         inf

# %% [markdown]
# The data contain large outliers (both positive and negative) in all of the numeric columns of interest.
#
# Below, the data are trimmed to retain values that fall between the 1st and 99th percentiles (middle 98% of the data).

# %% [markdown]
# ### Removing Outliers

# %%
# Trim dataset by finding the respective quantiles and removing all data above & below:
# Extract the numeric columns and remove outliers:
qlow = df.quantile(0.01)
qhigh = df.quantile(0.99)
df_num = df.iloc[:,np.r_[8:17,19,24,25]].columns
df_num = df[df_num][~((df[df_num] < qlow) |(df[df_num]> qhigh))]

# Create new dataframe with outliers removed:
dfs = [df.iloc[:,np.r_[0:8,17:19,20:24]], df_num]
df = pd.concat(dfs, axis = 1)

# %%
df.shape
# Out:
# (1000000, 26)

# %%
# Inspect cleaned dataset:
df.describe()
# Out:
#             VendorID     RatecodeID    PULocationID    DOLocationID  \
# count  964310.000000  964310.000000  1000000.000000  1000000.000000
# mean        1.739731       1.121494      135.733788      145.395178
# std         0.450038       0.828691       74.130092       75.201297
# min         1.000000       1.000000        1.000000        1.000000
# 25%         1.000000       1.000000       74.000000       75.000000
# 50%         2.000000       1.000000      137.000000      145.000000
# 75%         2.000000       1.000000      196.000000      226.000000
# max         4.000000      99.000000      265.000000      265.000000
#
#        passenger_count   payment_type      trip_type  trip_distance  \
# count    964310.000000  964310.000000  465792.000000  988435.000000
# mean          1.440658       1.362257       1.044333       2.968830
# std           1.107623       0.505524       0.205834       3.344175
# min           0.000000       1.000000       1.000000       0.000000
# 25%           1.000000       1.000000       1.000000       1.000000
# 50%           1.000000       1.000000       1.000000       1.760000
# 75%           1.000000       2.000000       1.000000       3.400000
# max           9.000000       5.000000       2.000000      19.300000
#
#          fare_amount          extra        mta_tax     tip_amount  \
# count  986025.000000  992405.000000  997527.000000  990113.000000
# mean       13.332396       0.788385       0.491122       1.453568
# std        10.302017       1.048525       0.066033       1.937792
# min         2.500000       0.000000       0.000000       0.000000
# 25%         6.500000       0.000000       0.500000       0.000000
# 50%        10.000000       0.500000       0.500000       1.000000
# 75%        16.000000       1.000000       0.500000       2.350000
# max        57.500000       3.500000       0.500000      11.780000
#
#         tolls_amount  ehail_fee  improvement_surcharge   total_amount  \
# count  996934.000000       25.0          997525.000000  980385.000000
# mean        0.278222        0.0               0.285297      17.623504
# std         1.255454        0.0               0.064767      12.090201
# min         0.000000        0.0               0.000000       4.300000
# 25%         0.000000        0.0               0.300000       9.800000
# 50%         0.000000        0.0               0.300000      13.800000
# 75%         0.000000        0.0               0.300000      20.760000
# max         6.120000        0.0               0.300000      73.670000
#
#        congestion_surcharge      trip_time     trip_speed
# count         891090.000000  989998.000000  971406.000000
# mean               1.346693      14.174427      12.321490
# std                1.264826      11.455832       5.979414
# min                0.000000       0.000000       0.076395
# 25%                0.000000       6.000000       8.350000
# 50%                2.500000      11.000000      11.000000
# 75%                2.500000      18.000000      14.800000
# max                2.750000      69.000000      39.504000

# %% [markdown]
# ## Visualizing the Data

# %% [markdown]
# Now that we've cleaned the dataset, we can visualize to get a better understanding of the characteristics of trips between yellow and green cabs, and understand tip amounts amongst all trips.

# %% [markdown]
# ### Total Fare Amount

# %%
sns.distplot(df[df['cab'] == 'green']['total_amount'], hist=False, color = "green")
sns.distplot(df[df['cab'] == "yellow"]['total_amount'], hist=False, color = "y").set_title('Total Fare Amount')
# Out:
# Text(0.5, 1.0, 'Total Fare Amount')

# %%
df.groupby('cab')['total_amount'].mean()
# Out:
# cab
# green     17.034789
# yellow    18.211387
# Name: total_amount, dtype: float64

# %% [markdown]
# On average, the total fare amount for yellow cabs is slightly greater than green cabs. We can check if this is due to longer trip times & higher distances traveled in yellow cabs than green cabs, shown below:

# %% [markdown]
# ### Total Trip Time

# %%
sns.distplot(df[df['cab']=="green"]['trip_time'], hist = False, color = "green")
sns.distplot(df[df['cab']=="yellow"]['trip_time'], hist = False, color = "y").set_title('Total Trip Time')
# Out:
# Text(0.5, 1.0, 'Total Trip Time')

# %%
df.groupby('cab')['trip_time'].mean()
# Out:
# cab
# green     14.632187
# yellow    13.719338
# Name: trip_time, dtype: float64

# %%
sns.distplot(df[df['cab']=="green"]['trip_distance'], hist = False, color = "green")
sns.distplot(df[df['cab']=="yellow"]['trip_distance'], hist = False, color = "y").set_title('Total Trip Distance')
# Out:
# Text(0.5, 1.0, 'Total Trip Distance')

# %%
df.groupby('cab')['trip_distance'].mean()
# Out:
# cab
# green     3.123170
# yellow    2.815008
# Name: trip_distance, dtype: float64

# %% [markdown]
# On average, the trip times and distances are approximately the same between both cabs (13-14 minutes and 3 miles, respectively).

# %% [markdown]
# ### Total Tip Amount

# %%
sns.distplot(df[df['cab']=="green"]['tip_amount'], hist = False, color = "green")
sns.distplot(df[df['cab']=="yellow"]['tip_amount'], hist = False, color = "y").set_title('Total Tip Amount')
# Out:
# Text(0.5, 1.0, 'Total Tip Amount')

# %%
df[df['tip_amount'] == 0].groupby('cab')['tip_amount'].count()
# Out:
# cab
# green     322460
# yellow    155231
# Name: tip_amount, dtype: int64

# %%
df[df['tip_amount'] > 0].groupby('cab')['tip_amount'].count()
# Out:
# cab
# green     176267
# yellow    336155
# Name: tip_amount, dtype: int64

# %% [markdown]
# There are a large portion of transactions have 0 tips for both cabs.
# * For green, approximately 60% of all transactions don't have tips.
# * For yellow, approximately 30% of all transactions dont have tips.
#
# Most of the 0 tip transactions are cash **(shown below - 'payment_type = 2')**.
# * 87% of no-tip transactions in yellow cabs are cash (9% are credit card)
# * 61% of no-tip transactions in green cabs are cash (27% are credit card).
#
# This could mean that taxi cab drivers do not record tip amounts for cash transcations (possibly for tax reasons).

# %%
df[df['tip_amount'] == 0].groupby(['cab', 'payment_type'])['payment_type'].count()
# Out:
# cab     payment_type
# green   1.0              88210
#         2.0             196555
#         3.0               2502
#         4.0               1014
#         5.0                 23
# yellow  1.0              14152
#         2.0             135746
#         3.0               2699
#         4.0               1132
#         5.0                  1
# Name: payment_type, dtype: int64

# %% [markdown]
# ### Trip Speed vs. Tip Amount

# %%
sns.jointplot('trip_speed', 'tip_amount', data = df, kind = 'hex')

# %%
# Pearson correlation coefficient of trip speed and tip amount:
df[['trip_speed','tip_amount']].corr()
# Out:
#             trip_speed  tip_amount
# trip_speed    1.000000    0.124781
# tip_amount    0.124781    1.000000

# %% [markdown]
# ### Summary of Tips by Payment Type & Borough

# %%
df.groupby(['cab', 'payment_type'])['tip_amount'].describe()
# Out:
#                         count      mean       std  min   25%   50%   75%  \
# cab    payment_type
# green  1.0           264442.0  1.772986  1.903343  0.0  0.00  1.50  2.61
#        2.0           196563.0  0.000048  0.008161  0.0  0.00  0.00  0.00
#        3.0             2505.0  0.005253  0.186133  0.0  0.00  0.00  0.00
#        4.0             1014.0  0.000000  0.000000  0.0  0.00  0.00  0.00
#        5.0               23.0  0.000000  0.000000  0.0  0.00  0.00  0.00
# yellow 1.0           350287.0  2.769559  1.950480  0.0  1.66  2.26  3.32
#        2.0           135758.0  0.000230  0.027337  0.0  0.00  0.00  0.00
#        3.0             2701.0  0.001129  0.050149  0.0  0.00  0.00  0.00
#        4.0             1134.0  0.003898  0.095605  0.0  0.00  0.00  0.00
#        5.0                1.0  0.000000       NaN  0.0  0.00  0.00  0.00
#
#                        max
# cab    payment_type
# green  1.0           11.78
#        2.0            2.00
#        3.0            8.49
#        4.0            0.00
#        5.0            0.00
# yellow 1.0           11.78
#        2.0            6.24
#        3.0            2.56
#        4.0            2.76
#        5.0            0.00

# %%
df.groupby('Borough')['tip_amount'].describe()
# Out:
#                   count      mean       std  min  25%  50%   75%    max
# Borough
# Bronx           36015.0  0.190703  0.956650  0.0  0.0  0.0  0.00  11.76
# Brooklyn       148788.0  1.091494  1.793593  0.0  0.0  0.0  1.89  11.76
# EWR                31.0  2.468065  4.156996  0.0  0.0  0.0  5.00  11.50
# Manhattan      621692.0  1.661448  1.792728  0.0  0.0  1.5  2.56  11.78
# Queens         177349.0  1.282133  2.455182  0.0  0.0  0.0  1.75  11.78
# Staten Island     297.0  0.383906  1.437080  0.0  0.0  0.0  0.00   9.57
# Unknown          5941.0  1.589485  2.194178  0.0  0.0  1.0  2.35  11.78
